# %%
import pandas as pd
import numpy as np

# %%
#Read datasets into pandas dataframes for manipulation
ebola  = pd.read_csv('data/data-ebola-public.csv')                    #Read in ebola case data

# %% [markdown]
# #Ebola Data Cleanup Tasks#
# Note: I manuall remove Link, Localite and Missing rows in this dataset using excel.
# *1. Pivot across Categories *
# The ebola data currently has a single column called category which contains the following types of Ebolas cases:
# - Cases
# - Deaths
# - Suspected Cases
# - Confirmed Cases
# - Probable Cases
#
# We want to pivot the row values into distinct columns. That is we want to create 5 new columns for each of category types

# %%
#1. Pivot across these category types
ebola_pivot = ebola.pivot_table('Value', ['Country','Date'], 'Category', aggfunc = np.mean)
ebola = ebola_pivot.reset_index()   #Reset DF index

#2. fill missing values is nan
ebola.fillna('nan')
# Out:
# Category       Country     Date      Cases Confirmed cases     Deaths  \
# 0               Guinea  03/2014       96.6              24   66.16667
# 1               Guinea  04/2014   59.62069           89.75   40.42308
# 2               Guinea  05/2014   67.48276         136.875   45.36207
# 3               Guinea  06/2014   81.57971             247   54.69565
# 4               Guinea  07/2014        417           302.4      312.2
# 5               Guinea  08/2014    92.8836        73.33333   63.67816
# 6               Guinea  09/2014   100.1046        79.80392   62.97168
# 7               Guinea  10/2014   126.1686        100.6244   74.80992
# 8               Guinea  11/2014   153.1782        131.4061   92.22222
# 9              Liberia  04/2014   10.52941        5.555556   4.617647
# 10             Liberia  05/2014   4.545455               6         11
# 11             Liberia  06/2014         15            21.3      15.16
# 12             Liberia  07/2014   192.4444        73.77778   109.5556
# 13             Liberia  08/2014   211.6497         49.2973   118.5478
# 14             Liberia  09/2014   370.8895        103.6474   201.2473
# 15             Liberia  10/2014     628.63        203.4097    302.435
# 16             Liberia  11/2014   852.4844          321.25   355.8594
# 17                Mali  10/2014  0.4615385       0.4230769  0.3461538
# 18                Mali  11/2014  0.9677419       0.7741935  0.8064516
# 19             Nigeria  07/2014        nan             nan          1
# 20             Nigeria  08/2014   14.82143            10.1   4.571429
# 21             Nigeria  09/2014   13.66667        12.64286   5.285714
# 22             Senegal  08/2014          1               1        nan
# 23             Senegal  09/2014   1.058824       0.9032258          0
# 24        Sierra Leone  05/2014   15.28571            7.25          3
# 25        Sierra Leone  06/2014   46.06897              89   14.03448
# 26        Sierra Leone  07/2014   403.4444        347.5556   182.5556
# 27        Sierra Leone  08/2014   147.3117        132.4679   60.06494
# 28        Sierra Leone  09/2014   242.5653        212.1013   71.16267
# 29        Sierra Leone  10/2014   495.5397        430.8877   166.6055
# 30        Sierra Leone  11/2014   695.1111        687.6444   373.8725
#
# Category   New cases Probable cases Suspected cases
# 0                nan             78              19
# 1                nan           38.5            53.5
# 2                nan            nan             nan
# 3                nan            nan             nan
# 4                nan            nan             nan
# 5           3.627907       18.37838             nan
# 6           2.061002       16.59259        3.708061
# 7           2.140458       15.98512        5.532231
# 8            2.09965        16.7069        5.065134
# 9                nan            nan             nan
# 10               nan            nan             nan
# 11               nan            nan             nan
# 12               nan            nan             nan
# 13          9.969697        90.5098             nan
# 14          8.610526       168.3842        99.84153
# 15          5.447917       218.3264        235.1111
# 16          4.953125       210.9375        320.2969
# 17        0.07692308              0               0
# 18        0.06451613      0.1612903               0
# 19               nan            nan             nan
# 20          2.166667            0.7             nan
# 21         0.2380952      0.6666667       0.2564103
# 22               nan            nan             nan
# 23          0.137931              0       0.4482759
# 24               nan            nan              22
# 25               nan            nan             nan
# 26               nan            nan             nan
# 27          5.768421              5             nan
# 28          6.216667          4.736        18.06933
# 29          9.024658       6.547945        58.10411
# 30               8.6       18.58824        210.8137

# %%
#Out CSV


#Build Json
json = {}
cols = ebola.columns
for r in range(0,len(ebola)):
    json[r] = {}
    for col in cols:
        if (ebola.irow(r)[col] != ebola.irow(r)[col]):
            json[r][col] = "nan"
        else:
            json[r][col] = ebola.irow(r)[col]
print json
# Out:
# {0: {'Suspected cases': 19.0, 'Confirmed cases': 24.0, 'Deaths': 66.166666666666671, 'Country': 'Guinea', 'New cases': 'nan', 'Date': '03/2014', 'Cases': 96.599999999999994, 'Probable cases': 78.0}, 1: {'Suspected cases': 53.5, 'Confirmed cases': 89.75, 'Deaths': 40.42307692307692, 'Country': 'Guinea', 'New cases': 'nan', 'Date': '04/2014', 'Cases': 59.620689655172413, 'Probable cases': 38.5}, 2: {'Suspected cases': 'nan', 'Confirmed cases': 136.875, 'Deaths': 45.362068965517238, 'Country': 'Guinea', 'New cases': 'nan', 'Date': '05/2014', 'Cases': 67.482758620689651, 'Probable cases': 'nan'}, 3: {'Suspected cases': 'nan', 'Confirmed cases': 247.0, 'Deaths': 54.695652173913047, 'Country': 'Guinea', 'New cases': 'nan', 'Date': '06/2014', 'Cases': 81.579710144927532, 'Probable cases': 'nan'}, 4: {'Suspected cases': 'nan', 'Confirmed cases': 302.39999999999998, 'Deaths': 312.19999999999999, 'Country': 'Guinea', 'New cases': 'nan', 'Date': '07/2014', 'Cases': 417.0, 'Probable cases': 'nan'}, 5: {'Suspected cases': 'nan', 'Confirmed cases': 73.333333333333329, 'Deaths': 63.678160919540232, 'Country': 'Guinea', 'New cases': 3.6279069767441858, 'Date': '08/2014', 'Cases': 92.883597883597886, 'Probable cases': 18.378378378378379}, 6: {'Suspected cases': 3.7080610021786491, 'Confirmed cases': 79.803921568627445, 'Deaths': 62.971677559912855, 'Country': 'Guinea', 'New cases': 2.0610021786492374, 'Date': '09/2014', 'Cases': 100.10457516339869, 'Probable cases': 16.592592592592592}, 7: {'Suspected cases': 5.5322314049586776, 'Confirmed cases': 100.62442748091603, 'Deaths': 74.809917355371894, 'Country': 'Guinea', 'New cases': 2.1404580152671757, 'Date': '10/2014', 'Cases': 126.16859504132232, 'Probable cases': 15.985123966942149}, 8: {'Suspected cases': 5.0651340996168583, 'Confirmed cases': 131.40613026819923, 'Deaths': 92.222222222222229, 'Country': 'Guinea', 'New cases': 2.0996503496503496, 'Date': '11/2014', 'Cases': 153.17816091954023, 'Probable cases': 16.706896551724139}, 9: {'Suspected cases': 'nan', 'Confirmed cases': 5.5555555555555554, 'Deaths': 4.617647058823529, 'Country': 'Liberia', 'New cases': 'nan', 'Date': '04/2014', 'Cases': 10.529411764705882, 'Probable cases': 'nan'}, 10: {'Suspected cases': 'nan', 'Confirmed cases': 6.0, 'Deaths': 11.0, 'Country': 'Liberia', 'New cases': 'nan', 'Date': '05/2014', 'Cases': 4.5454545454545459, 'Probable cases': 'nan'}, 11: {'Suspected cases': 'nan', 'Confirmed cases': 21.300000000000001, 'Deaths': 15.16, 'Country': 'Liberia', 'New cases': 'nan', 'Date': '06/2014', 'Cases': 15.0, 'Probable cases': 'nan'}, 12: {'Suspected cases': 'nan', 'Confirmed cases': 73.777777777777771, 'Deaths': 109.55555555555556, 'Country': 'Liberia', 'New cases': 'nan', 'Date': '07/2014', 'Cases': 192.44444444444446, 'Probable cases': 'nan'}, 13: {'Suspected cases': 'nan', 'Confirmed cases': 49.297297297297298, 'Deaths': 118.54777070063695, 'Country': 'Liberia', 'New cases': 9.9696969696969688, 'Date': '08/2014', 'Cases': 211.64968152866243, 'Probable cases': 90.509803921568633}, 14: {'Suspected cases': 99.841530054644807, 'Confirmed cases': 103.64736842105263, 'Deaths': 201.24725274725276, 'Country': 'Liberia', 'New cases': 8.6105263157894729, 'Date': '09/2014', 'Cases': 370.88947368421054, 'Probable cases': 168.3842105263158}, 15: {'Suspected cases': 235.11111111111111, 'Confirmed cases': 203.40972222222223, 'Deaths': 302.435, 'Country': 'Liberia', 'New cases': 5.447916666666667, 'Date': '10/2014', 'Cases': 628.63, 'Probable cases': 218.32638888888889}, 16: {'Suspected cases': 320.296875, 'Confirmed cases': 321.25, 'Deaths': 355.859375, 'Country': 'Liberia', 'New cases': 4.953125, 'Date': '11/2014', 'Cases': 852.484375, 'Probable cases': 210.9375}, 17: {'Suspected cases': 0.0, 'Confirmed cases': 0.42307692307692307, 'Deaths': 0.34615384615384615, 'Country': 'Mali', 'New cases': 0.076923076923076927, 'Date': '10/2014', 'Cases': 0.46153846153846156, 'Probable cases': 0.0}, 18: {'Suspected cases': 0.0, 'Confirmed  ...
